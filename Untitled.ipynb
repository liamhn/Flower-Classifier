# %%
import keras
from numpy import *
from pylab import *

import keras.models as km, keras.layers as kl
import keras.utils as ku

from tensorflow import keras

import tensorflow as tf

#Options:
nNodes_conv1 = 25
nNodes_conv2 = 25
numFlat = 200
d_rate = 0.7

xdata = load("50x50flowers.images.npy")
ydata = load("50x50flowers.targets.npy")

xnormed = xdata/255
ynormed = tf.keras.utils.to_categorical(ydata,18)

xtrain= xnormed[:1000]
ytrain = ynormed[:1000]

#can we make more data, add 2 data for each data, flipping along the two available axes
x_tend = zeros((xtrain.shape[0]*3,xtrain.shape[1],xtrain.shape[2],xtrain.shape[3]))
y_tend = zeros((ytrain.shape[0]*3,ytrain.shape[1]))

for i in range(len(xtrain)):
    x_tend[i] = xtrain[i]
    x_tend[2*i]=flip(xtrain[i],axis =0)
    x_tend[3*i]=flip(xtrain[i],axis =1)
    
    y_tend[i] = ytrain[i]
    y_tend[2*i]=ytrain[i]
    y_tend[3*i]=ytrain[i]


xtest = xnormed[1000:]
ytest = ynormed[1000:]

model = km.Sequential()
model.add(kl.Conv2D(nNodes_conv1,kernel_size = (5,5),input_shape = xtrain[0].shape,activation = "relu"))
model.add(kl.MaxPooling2D(pool_size = (2,2),strides = (2,2)))
model.add(kl.Conv2D(nNodes_conv2,kernel_size = (3,3),activation = 'relu'))
model.add(kl.MaxPooling2D(pool_size = (2,2),strides = (2,2)))
model.add(kl.Flatten())
model.add(kl.Dense(numFlat,activation = "tanh"))
model.add(kl.Dropout(d_rate,name = 'dropout'))
model.add(kl.Dense(18,activation = 'softmax'))

model.compile(loss = "categorical_crossentropy", optimizer = "sgd", metrics = ["accuracy"])
fit = model.fit(x_tend,y_tend,epochs = 300, batch_size = 100, verbose = 2)

score = model.evaluate(xtest, ytest)
print(score)
# Out:
# Epoch 1/300
# 30/30 - 2s - loss: 1.9286 - accuracy: 0.0610 - 2s/epoch - 71ms/step
# Epoch 2/300
# 30/30 - 2s - loss: 1.9019 - accuracy: 0.0513 - 2s/epoch - 60ms/step
# Epoch 3/300
# 30/30 - 2s - loss: 1.8684 - accuracy: 0.0590 - 2s/epoch - 59ms/step
# Epoch 4/300
# 30/30 - 2s - loss: 1.8368 - accuracy: 0.0757 - 2s/epoch - 59ms/step
# Epoch 5/300
# 30/30 - 2s - loss: 1.7922 - accuracy: 0.0983 - 2s/epoch - 60ms/step
# Epoch 6/300
# 30/30 - 2s - loss: 1.7223 - accuracy: 0.1183 - 2s/epoch - 59ms/step
# Epoch 7/300
# 30/30 - 2s - loss: 1.6746 - accuracy: 0.1203 - 2s/epoch - 60ms/step
# Epoch 8/300
# 30/30 - 2s - loss: 1.6358 - accuracy: 0.1417 - 2s/epoch - 59ms/step
# Epoch 9/300
# 30/30 - 2s - loss: 1.5954 - accuracy: 0.1610 - 2s/epoch - 59ms/step
# Epoch 10/300
# 30/30 - 2s - loss: 1.5843 - accuracy: 0.1647 - 2s/epoch - 59ms/step
# Epoch 11/300
# 30/30 - 2s - loss: 1.5404 - accuracy: 0.1767 - 2s/epoch - 59ms/step
# Epoch 12/300
# 30/30 - 2s - loss: 1.5226 - accuracy: 0.1733 - 2s/epoch - 59ms/step
# Epoch 13/300
# 30/30 - 2s - loss: 1.5287 - accuracy: 0.1730 - 2s/epoch - 60ms/step
# Epoch 14/300
# 30/30 - 2s - loss: 1.4866 - accuracy: 0.1963 - 2s/epoch - 60ms/step
# Epoch 15/300
# 30/30 - 2s - loss: 1.4780 - accuracy: 0.2010 - 2s/epoch - 60ms/step
# Epoch 16/300
# 30/30 - 2s - loss: 1.4577 - accuracy: 0.2060 - 2s/epoch - 61ms/step
# Epoch 17/300
# 30/30 - 2s - loss: 1.4315 - accuracy: 0.2057 - 2s/epoch - 60ms/step
# Epoch 18/300
# 30/30 - 2s - loss: 1.4392 - accuracy: 0.2100 - 2s/epoch - 62ms/step
# Epoch 19/300
# 30/30 - 2s - loss: 1.3957 - accuracy: 0.2213 - 2s/epoch - 63ms/step
# Epoch 20/300
# 30/30 - 2s - loss: 1.3870 - accuracy: 0.2213 - 2s/epoch - 63ms/step
# Epoch 21/300
# 30/30 - 2s - loss: 1.3487 - accuracy: 0.2360 - 2s/epoch - 59ms/step
# Epoch 22/300
# 30/30 - 2s - loss: 1.3534 - accuracy: 0.2277 - 2s/epoch - 59ms/step
# Epoch 23/300
# 30/30 - 2s - loss: 1.3133 - accuracy: 0.2463 - 2s/epoch - 60ms/step
# Epoch 24/300
# 30/30 - 2s - loss: 1.3029 - accuracy: 0.2533 - 2s/epoch - 60ms/step
# Epoch 25/300
# 30/30 - 2s - loss: 1.2856 - accuracy: 0.2570 - 2s/epoch - 59ms/step
# Epoch 26/300
# 30/30 - 2s - loss: 1.2771 - accuracy: 0.2583 - 2s/epoch - 59ms/step
# Epoch 27/300
# 30/30 - 2s - loss: 1.2695 - accuracy: 0.2647 - 2s/epoch - 59ms/step
# Epoch 28/300
# 30/30 - 2s - loss: 1.2427 - accuracy: 0.2713 - 2s/epoch - 59ms/step
# Epoch 29/300
# 30/30 - 2s - loss: 1.2294 - accuracy: 0.2727 - 2s/epoch - 61ms/step
# Epoch 30/300
# 30/30 - 2s - loss: 1.2050 - accuracy: 0.2877 - 2s/epoch - 62ms/step
# Epoch 31/300
# 30/30 - 2s - loss: 1.1993 - accuracy: 0.2847 - 2s/epoch - 59ms/step
# Epoch 32/300
# 30/30 - 2s - loss: 1.1629 - accuracy: 0.3073 - 2s/epoch - 59ms/step
# Epoch 33/300
# 30/30 - 2s - loss: 1.1539 - accuracy: 0.3030 - 2s/epoch - 60ms/step
# Epoch 34/300
# 30/30 - 2s - loss: 1.1553 - accuracy: 0.2997 - 2s/epoch - 60ms/step
# Epoch 35/300
# 30/30 - 2s - loss: 1.1364 - accuracy: 0.3123 - 2s/epoch - 59ms/step
# Epoch 36/300
# 30/30 - 2s - loss: 1.1202 - accuracy: 0.3137 - 2s/epoch - 59ms/step
# Epoch 37/300
# 30/30 - 2s - loss: 1.0946 - accuracy: 0.3200 - 2s/epoch - 59ms/step
# Epoch 38/300
# 30/30 - 2s - loss: 1.1067 - accuracy: 0.3107 - 2s/epoch - 58ms/step
# Epoch 39/300
# 30/30 - 2s - loss: 1.0768 - accuracy: 0.3297 - 2s/epoch - 59ms/step
# Epoch 40/300
# 30/30 - 2s - loss: 1.0818 - accuracy: 0.3283 - 2s/epoch - 60ms/step
# Epoch 41/300
# 30/30 - 2s - loss: 1.0530 - accuracy: 0.3443 - 2s/epoch - 59ms/step
# Epoch 42/300
# 30/30 - 2s - loss: 1.0476 - accuracy: 0.3313 - 2s/epoch - 59ms/step
# Epoch 43/300
# 30/30 - 2s - loss: 1.0236 - accuracy: 0.3523 - 2s/epoch - 60ms/step
# Epoch 44/300
# 30/30 - 2s - loss: 1.0215 - accuracy: 0.3453 - 2s/epoch - 61ms/step
# Epoch 45/300
# 30/30 - 2s - loss: 1.0265 - accuracy: 0.3417 - 2s/epoch - 59ms/step
# Epoch 46/300
# 30/30 - 2s - loss: 1.0186 - accuracy: 0.3513 - 2s/epoch - 60ms/step
# Epoch 47/300
# 30/30 - 2s - loss: 1.0188 - accuracy: 0.3493 - 2s/epoch - 59ms/step
# Epoch 48/300
# 30/30 - 2s - loss: 0.9779 - accuracy: 0.3613 - 2s/epoch - 59ms/step
# Epoch 49/300
# 30/30 - 2s - loss: 0.9744 - accuracy: 0.3637 - 2s/epoch - 62ms/step
# Epoch 50/300
# 30/30 - 2s - loss: 0.9942 - accuracy: 0.3573 - 2s/epoch - 62ms/step
# Epoch 51/300
# 30/30 - 2s - loss: 0.9598 - accuracy: 0.3767 - 2s/epoch - 60ms/step
# Epoch 52/300
# 30/30 - 2s - loss: 0.9473 - accuracy: 0.3800 - 2s/epoch - 60ms/step
# Epoch 53/300
# 30/30 - 2s - loss: 0.9551 - accuracy: 0.3663 - 2s/epoch - 59ms/step
# Epoch 54/300
# 30/30 - 2s - loss: 0.9345 - accuracy: 0.3780 - 2s/epoch - 62ms/step
# Epoch 55/300
# 30/30 - 2s - loss: 0.9220 - accuracy: 0.3740 - 2s/epoch - 61ms/step
# Epoch 56/300
# 30/30 - 2s - loss: 0.9303 - accuracy: 0.3823 - 2s/epoch - 62ms/step
# Epoch 57/300
# 30/30 - 2s - loss: 0.9234 - accuracy: 0.3807 - 2s/epoch - 61ms/step
# Epoch 58/300
# 30/30 - 2s - loss: 0.9033 - accuracy: 0.3833 - 2s/epoch - 69ms/step
# Epoch 59/300
# 30/30 - 2s - loss: 0.8927 - accuracy: 0.3953 - 2s/epoch - 68ms/step
# Epoch 60/300
# 30/30 - 2s - loss: 0.8951 - accuracy: 0.3917 - 2s/epoch - 69ms/step
# Epoch 61/300
# 30/30 - 2s - loss: 0.8973 - accuracy: 0.3957 - 2s/epoch - 66ms/step
# Epoch 62/300
# 30/30 - 2s - loss: 0.8790 - accuracy: 0.3943 - 2s/epoch - 67ms/step
# Epoch 63/300
# 30/30 - 2s - loss: 0.8784 - accuracy: 0.3947 - 2s/epoch - 62ms/step
# Epoch 64/300
# 30/30 - 2s - loss: 0.8776 - accuracy: 0.4067 - 2s/epoch - 62ms/step
# Epoch 65/300
# 30/30 - 2s - loss: 0.8535 - accuracy: 0.3940 - 2s/epoch - 61ms/step
# Epoch 66/300
# 30/30 - 2s - loss: 0.8623 - accuracy: 0.3990 - 2s/epoch - 61ms/step
# Epoch 67/300
# 30/30 - 2s - loss: 0.8456 - accuracy: 0.4083 - 2s/epoch - 61ms/step
# Epoch 68/300
# 30/30 - 2s - loss: 0.8566 - accuracy: 0.4047 - 2s/epoch - 64ms/step
# Epoch 69/300
# 30/30 - 2s - loss: 0.8430 - accuracy: 0.4110 - 2s/epoch - 64ms/step
# Epoch 70/300
# 30/30 - 2s - loss: 0.8410 - accuracy: 0.4110 - 2s/epoch - 60ms/step
# Epoch 71/300
# 30/30 - 2s - loss: 0.8421 - accuracy: 0.4027 - 2s/epoch - 62ms/step
# Epoch 72/300
# 30/30 - 2s - loss: 0.8374 - accuracy: 0.4130 - 2s/epoch - 60ms/step
# Epoch 73/300
# 30/30 - 2s - loss: 0.8217 - accuracy: 0.4167 - 2s/epoch - 60ms/step
# Epoch 74/300
# 30/30 - 2s - loss: 0.8165 - accuracy: 0.4177 - 2s/epoch - 61ms/step
# Epoch 75/300
# 30/30 - 2s - loss: 0.8197 - accuracy: 0.4113 - 2s/epoch - 61ms/step
# Epoch 76/300
# 30/30 - 2s - loss: 0.7920 - accuracy: 0.4240 - 2s/epoch - 63ms/step
# Epoch 77/300
# 30/30 - 2s - loss: 0.8086 - accuracy: 0.4263 - 2s/epoch - 62ms/step
# Epoch 78/300
# 30/30 - 2s - loss: 0.7919 - accuracy: 0.4277 - 2s/epoch - 61ms/step
# Epoch 79/300
# 30/30 - 2s - loss: 0.7943 - accuracy: 0.4297 - 2s/epoch - 63ms/step
# Epoch 80/300
# 30/30 - 2s - loss: 0.7929 - accuracy: 0.4280 - 2s/epoch - 60ms/step
# Epoch 81/300
# 30/30 - 2s - loss: 0.8070 - accuracy: 0.4133 - 2s/epoch - 61ms/step
# Epoch 82/300
# 30/30 - 2s - loss: 0.7925 - accuracy: 0.4303 - 2s/epoch - 61ms/step
# Epoch 83/300
# 30/30 - 2s - loss: 0.7839 - accuracy: 0.4250 - 2s/epoch - 62ms/step
# Epoch 84/300
# 30/30 - 2s - loss: 0.7806 - accuracy: 0.4277 - 2s/epoch - 63ms/step
# Epoch 85/300
# 30/30 - 2s - loss: 0.7871 - accuracy: 0.4197 - 2s/epoch - 62ms/step
# Epoch 86/300
# 30/30 - 2s - loss: 0.7743 - accuracy: 0.4270 - 2s/epoch - 60ms/step
# Epoch 87/300
# 30/30 - 2s - loss: 0.7771 - accuracy: 0.4303 - 2s/epoch - 60ms/step
# Epoch 88/300
# 30/30 - 2s - loss: 0.7649 - accuracy: 0.4383 - 2s/epoch - 66ms/step
# Epoch 89/300
# 30/30 - 2s - loss: 0.7701 - accuracy: 0.4333 - 2s/epoch - 64ms/step
# Epoch 90/300
# 30/30 - 2s - loss: 0.7576 - accuracy: 0.4467 - 2s/epoch - 64ms/step
# Epoch 91/300
# 30/30 - 2s - loss: 0.7498 - accuracy: 0.4360 - 2s/epoch - 61ms/step
# Epoch 92/300
# 30/30 - 2s - loss: 0.7499 - accuracy: 0.4443 - 2s/epoch - 61ms/step
# Epoch 93/300
# 30/30 - 2s - loss: 0.7568 - accuracy: 0.4323 - 2s/epoch - 63ms/step
# Epoch 94/300
# 30/30 - 2s - loss: 0.7385 - accuracy: 0.4530 - 2s/epoch - 69ms/step
# Epoch 95/300
# 30/30 - 2s - loss: 0.7369 - accuracy: 0.4500 - 2s/epoch - 63ms/step
# Epoch 96/300
# 30/30 - 2s - loss: 0.7391 - accuracy: 0.4457 - 2s/epoch - 63ms/step
# Epoch 97/300
# 30/30 - 2s - loss: 0.7340 - accuracy: 0.4570 - 2s/epoch - 60ms/step
# Epoch 98/300
# 30/30 - 2s - loss: 0.7233 - accuracy: 0.4533 - 2s/epoch - 60ms/step
# Epoch 99/300
# 30/30 - 2s - loss: 0.7321 - accuracy: 0.4473 - 2s/epoch - 60ms/step
# Epoch 100/300
# 30/30 - 2s - loss: 0.7306 - accuracy: 0.4440 - 2s/epoch - 60ms/step
# Epoch 101/300
# 30/30 - 2s - loss: 0.7194 - accuracy: 0.4603 - 2s/epoch - 62ms/step
# Epoch 102/300
# 30/30 - 2s - loss: 0.7182 - accuracy: 0.4480 - 2s/epoch - 62ms/step
# Epoch 103/300
# 30/30 - 2s - loss: 0.7205 - accuracy: 0.4493 - 2s/epoch - 61ms/step
# Epoch 104/300
# 30/30 - 2s - loss: 0.6961 - accuracy: 0.4653 - 2s/epoch - 61ms/step
# Epoch 105/300
# 30/30 - 2s - loss: 0.7173 - accuracy: 0.4457 - 2s/epoch - 60ms/step
# Epoch 106/300
# 30/30 - 2s - loss: 0.7150 - accuracy: 0.4537 - 2s/epoch - 63ms/step
# Epoch 107/300
# 30/30 - 2s - loss: 0.6999 - accuracy: 0.4633 - 2s/epoch - 61ms/step
# Epoch 108/300
# 30/30 - 2s - loss: 0.7010 - accuracy: 0.4597 - 2s/epoch - 63ms/step
# Epoch 109/300
# 30/30 - 2s - loss: 0.6978 - accuracy: 0.4577 - 2s/epoch - 62ms/step
# Epoch 110/300
# 30/30 - 2s - loss: 0.6880 - accuracy: 0.4603 - 2s/epoch - 60ms/step
# Epoch 111/300
# 30/30 - 2s - loss: 0.6790 - accuracy: 0.4627 - 2s/epoch - 61ms/step
# Epoch 112/300
# 30/30 - 2s - loss: 0.6795 - accuracy: 0.4610 - 2s/epoch - 61ms/step
# Epoch 113/300
# 30/30 - 2s - loss: 0.6895 - accuracy: 0.4560 - 2s/epoch - 61ms/step
# Epoch 114/300
# 30/30 - 2s - loss: 0.6842 - accuracy: 0.4590 - 2s/epoch - 61ms/step
# Epoch 115/300
# 30/30 - 2s - loss: 0.6886 - accuracy: 0.4690 - 2s/epoch - 60ms/step
# Epoch 116/300
# 30/30 - 2s - loss: 0.6772 - accuracy: 0.4653 - 2s/epoch - 61ms/step
# Epoch 117/300
# 30/30 - 2s - loss: 0.6764 - accuracy: 0.4713 - 2s/epoch - 62ms/step
# Epoch 118/300
# 30/30 - 2s - loss: 0.6586 - accuracy: 0.4700 - 2s/epoch - 62ms/step
# Epoch 119/300
# 30/30 - 2s - loss: 0.6782 - accuracy: 0.4683 - 2s/epoch - 60ms/step
# Epoch 120/300
# 30/30 - 2s - loss: 0.6608 - accuracy: 0.4747 - 2s/epoch - 60ms/step
# Epoch 121/300
# 30/30 - 2s - loss: 0.6584 - accuracy: 0.4707 - 2s/epoch - 61ms/step
# Epoch 122/300
# 30/30 - 2s - loss: 0.6645 - accuracy: 0.4577 - 2s/epoch - 61ms/step
# Epoch 123/300
# 30/30 - 2s - loss: 0.6621 - accuracy: 0.4713 - 2s/epoch - 62ms/step
# Epoch 124/300
# 30/30 - 2s - loss: 0.6428 - accuracy: 0.4767 - 2s/epoch - 62ms/step
# Epoch 125/300
# 30/30 - 2s - loss: 0.6430 - accuracy: 0.4763 - 2s/epoch - 61ms/step
# Epoch 126/300
# 30/30 - 2s - loss: 0.6510 - accuracy: 0.4727 - 2s/epoch - 65ms/step
# Epoch 127/300
# 30/30 - 2s - loss: 0.6545 - accuracy: 0.4750 - 2s/epoch - 69ms/step
# Epoch 128/300
# 30/30 - 2s - loss: 0.6389 - accuracy: 0.4820 - 2s/epoch - 66ms/step
# Epoch 129/300
# 30/30 - 2s - loss: 0.6451 - accuracy: 0.4757 - 2s/epoch - 63ms/step
# Epoch 130/300
# 30/30 - 2s - loss: 0.6387 - accuracy: 0.4770 - 2s/epoch - 61ms/step
# Epoch 131/300
# 30/30 - 2s - loss: 0.6183 - accuracy: 0.4870 - 2s/epoch - 62ms/step
# Epoch 132/300
# 30/30 - 2s - loss: 0.6390 - accuracy: 0.4730 - 2s/epoch - 62ms/step
# Epoch 133/300
# 30/30 - 2s - loss: 0.6283 - accuracy: 0.4823 - 2s/epoch - 62ms/step
# Epoch 134/300
# 30/30 - 2s - loss: 0.6332 - accuracy: 0.4770 - 2s/epoch - 62ms/step
# Epoch 135/300
# 30/30 - 2s - loss: 0.6181 - accuracy: 0.4890 - 2s/epoch - 60ms/step
# Epoch 136/300
# 30/30 - 2s - loss: 0.6294 - accuracy: 0.4817 - 2s/epoch - 63ms/step
# Epoch 137/300
# 30/30 - 2s - loss: 0.6161 - accuracy: 0.4877 - 2s/epoch - 62ms/step
# Epoch 138/300
# 30/30 - 2s - loss: 0.6236 - accuracy: 0.4800 - 2s/epoch - 61ms/step
# Epoch 139/300
# 30/30 - 2s - loss: 0.6160 - accuracy: 0.4887 - 2s/epoch - 62ms/step
# Epoch 140/300
# 30/30 - 2s - loss: 0.6192 - accuracy: 0.4837 - 2s/epoch - 65ms/step
# Epoch 141/300
# 30/30 - 2s - loss: 0.6086 - accuracy: 0.4867 - 2s/epoch - 63ms/step
# Epoch 142/300
# 30/30 - 2s - loss: 0.5972 - accuracy: 0.4940 - 2s/epoch - 63ms/step
# Epoch 143/300
# 30/30 - 2s - loss: 0.6009 - accuracy: 0.4893 - 2s/epoch - 61ms/step
# Epoch 144/300
# 30/30 - 2s - loss: 0.5879 - accuracy: 0.4867 - 2s/epoch - 62ms/step
# Epoch 145/300
# 30/30 - 2s - loss: 0.5824 - accuracy: 0.4960 - 2s/epoch - 61ms/step
# Epoch 146/300
# 30/30 - 2s - loss: 0.6008 - accuracy: 0.4943 - 2s/epoch - 61ms/step
# Epoch 147/300
# 30/30 - 2s - loss: 0.5924 - accuracy: 0.4980 - 2s/epoch - 62ms/step
# Epoch 148/300
# 30/30 - 2s - loss: 0.5858 - accuracy: 0.4947 - 2s/epoch - 61ms/step
# Epoch 149/300
# 30/30 - 2s - loss: 0.5919 - accuracy: 0.4917 - 2s/epoch - 63ms/step
# Epoch 150/300
# 30/30 - 2s - loss: 0.5873 - accuracy: 0.4950 - 2s/epoch - 68ms/step
# Epoch 151/300
# 30/30 - 2s - loss: 0.5875 - accuracy: 0.4957 - 2s/epoch - 67ms/step
# Epoch 152/300
# 30/30 - 2s - loss: 0.5689 - accuracy: 0.5010 - 2s/epoch - 67ms/step
# Epoch 153/300
# 30/30 - 2s - loss: 0.5866 - accuracy: 0.4840 - 2s/epoch - 67ms/step
# Epoch 154/300
# 30/30 - 2s - loss: 0.5831 - accuracy: 0.4973 - 2s/epoch - 64ms/step
# Epoch 155/300
# 30/30 - 2s - loss: 0.5657 - accuracy: 0.5063 - 2s/epoch - 64ms/step
# Epoch 156/300
# 30/30 - 2s - loss: 0.5770 - accuracy: 0.4917 - 2s/epoch - 63ms/step
# Epoch 157/300
# 30/30 - 2s - loss: 0.5600 - accuracy: 0.5047 - 2s/epoch - 65ms/step
# Epoch 158/300
# 30/30 - 2s - loss: 0.5715 - accuracy: 0.5027 - 2s/epoch - 68ms/step
# Epoch 159/300
# 30/30 - 2s - loss: 0.5555 - accuracy: 0.5080 - 2s/epoch - 70ms/step
# Epoch 160/300
# 30/30 - 2s - loss: 0.5738 - accuracy: 0.4993 - 2s/epoch - 62ms/step
# Epoch 161/300
# 30/30 - 2s - loss: 0.5538 - accuracy: 0.5050 - 2s/epoch - 62ms/step
# Epoch 162/300
# 30/30 - 2s - loss: 0.5572 - accuracy: 0.5020 - 2s/epoch - 62ms/step
# Epoch 163/300
# 30/30 - 2s - loss: 0.5548 - accuracy: 0.5070 - 2s/epoch - 60ms/step
# Epoch 164/300
# 30/30 - 2s - loss: 0.5563 - accuracy: 0.5027 - 2s/epoch - 60ms/step
# Epoch 165/300
# 30/30 - 2s - loss: 0.5470 - accuracy: 0.5093 - 2s/epoch - 62ms/step
# Epoch 166/300
# 30/30 - 2s - loss: 0.5552 - accuracy: 0.4980 - 2s/epoch - 60ms/step
# Epoch 167/300
# 30/30 - 2s - loss: 0.5342 - accuracy: 0.5123 - 2s/epoch - 60ms/step
# Epoch 168/300
# 30/30 - 2s - loss: 0.5373 - accuracy: 0.5163 - 2s/epoch - 61ms/step
# Epoch 169/300
# 30/30 - 2s - loss: 0.5428 - accuracy: 0.5040 - 2s/epoch - 60ms/step
# Epoch 170/300
# 30/30 - 2s - loss: 0.5288 - accuracy: 0.5133 - 2s/epoch - 60ms/step
# Epoch 171/300
# 30/30 - 2s - loss: 0.5332 - accuracy: 0.5083 - 2s/epoch - 60ms/step
# Epoch 172/300
# 30/30 - 2s - loss: 0.5395 - accuracy: 0.5140 - 2s/epoch - 61ms/step
# Epoch 173/300
# 30/30 - 2s - loss: 0.5343 - accuracy: 0.5080 - 2s/epoch - 64ms/step
# Epoch 174/300
# 30/30 - 2s - loss: 0.5389 - accuracy: 0.5110 - 2s/epoch - 63ms/step
# Epoch 175/300
# 30/30 - 2s - loss: 0.5249 - accuracy: 0.5197 - 2s/epoch - 65ms/step
# Epoch 176/300
# 30/30 - 2s - loss: 0.5190 - accuracy: 0.5230 - 2s/epoch - 62ms/step
# Epoch 177/300

# %%
# Out:
# 1360
